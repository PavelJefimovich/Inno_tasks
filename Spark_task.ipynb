# %%
# 1
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as spark_sum, desc, count
from functools import reduce
import pandas as pd

spark = SparkSession.builder \
    .appName("Pagila Analysis") \
    .master("local[*]") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .getOrCreate()

# %%
# 2
film = spark.read.option("header", True).csv("data/film.csv")
actor = spark.read.option("header", True).csv("data/actor.csv")
category = spark.read.option("header", True).csv("data/category.csv")
film_category = spark.read.option("header", True).csv("data/film_category.csv")
inventory = spark.read.option("header", True).csv("data/inventory.csv")
customer = spark.read.option("header", True).csv("data/customer.csv")
address = spark.read.option("header", True).csv("data/address.csv")
city = spark.read.option("header", True).csv("data/city.csv")
rental = spark.read.option("header", True).csv("data/rental.csv")

# Объединение payment из 7 файлов
payments = []
for i in range(1, 8):
    p = spark.read.option("header", True).csv(f"data/payment_p2022_0{i}.csv")
    payments.append(p)
payment = reduce(lambda a, b: a.union(b), payments)

# %%
#3  Количество фильмов по категориям
cat_count = film_category.join(category, "category_id") \
    .groupBy("name").count() \
    .orderBy(desc("count"))


cat_count_pd = cat_count.toPandas()
cat_count_pd
# Out:
#            name  count
# 0         Drama    152
# 1         Music    152
# 2        Travel    151
# 3       Foreign    150
# 4         Games    150
# 5      Children    150
# 6        Action    149
# 7        Sci-Fi    149
# 8     Animation    148
# 9        Family    147
# 10     Classics    147
# 11          New    147
# 12       Sports    145
# 13  Documentary    145
# 14       Comedy    143
# 15       Horror    142

# %%
# 4: 10 актеров с наибольшим количеством аренд

# Соединяем фильм с актером через film_actor
film_actor = spark.read.option("header", True).csv("data/film_actor.csv")

# Соединяем inventory → rental → payment
rental_payment = rental.join(payment, "rental_id")

# Соединяем film_actor → film → inventory → rental → payment
actor_rentals = film_actor.join(inventory, "film_id") \
    .join(rental_payment, "inventory_id")

# Считаем количество аренд для каждого актера
actor_rent_count = actor_rentals.groupBy("actor_id") \
    .agg(count("rental_id").alias("rentals"))

# Добавляем имена актеров
actor_rent_count = actor_rent_count.join(actor, "actor_id") \
    .select("first_name", "last_name", "rentals") \
    .orderBy(desc("rentals"))

# топ 10
actor_rent_count_pd = actor_rent_count.limit(10).toPandas()
actor_rent_count_pd
# Out:
#   first_name    last_name  rentals
# 0       GINA    DEGENERES      753
# 1    MATTHEW       CARREY      678
# 2       MARY       KEITEL      674
# 3     ANGELA  WITHERSPOON      654
# 4     WALTER         TORN      640
# 5      HENRY        BERRY      612
# 6      JAYNE        NOLTE      611
# 7        VAL       BOLGER      605
# 8     SANDRA       KILMER      604
# 9       SEAN      GUINESS      599

# %%
# 5: категория с наибольшей суммой платежей

#  соединяем inventory → rental → payment
rental_payment = inventory.join(rental, "inventory_id") \
                          .join(payment, "rental_id")

# film → film_category → category
film_cat = film.join(film_category, "film_id").join(category, "category_id")

# Соединяем film_cat с rental_payment через film_id → inventory → rental → payment
cat_payment = film_cat.join(rental_payment, "film_id") \
    .groupBy("name") \
    .agg(spark_sum("amount").alias("total_amount")) \
    .orderBy(desc("total_amount"))

# категория с наибольшей суммой
cat_payment_pd = cat_payment.limit(1).toPandas()
cat_payment_pd
# Out:
#       name  total_amount
# 0  Foreign      10507.67

# %%
# 6: фильмы, которых нет в inventory
film_not_in_inventory = film.join(inventory, "film_id", "left_anti")
film_not_in_inventory_pd = film_not_in_inventory.toPandas()
film_not_in_inventory_pd
# Out:
#    film_id                   title  \
# 0       14          ALICE FANTASIA
# 1       33             APOLLO TEEN
# 2       36          ARGONAUTS TOWN
# 3       38           ARK RIDGEMONT
# 4       41    ARSENIC INDEPENDENCE
# 5       87       BOONDOCK BALLROOM
# 6      108           BUTCH PANTHER
# 7      128           CATCH AMISTAD
# 8      144     CHINATOWN GLADIATOR
# 9      148          CHOCOLATE DUCK
# 10     171    COMMANDMENTS EXPRESS
# 11     192        CROSSING DIVORCE
# 12     195         CROWDS TELEMARK
# 13     198        CRYSTAL BREAKING
# 14     217              DAZED PUNK
# 15     221  DELIVERANCE MULHOLLAND
# 16     318       FIREHOUSE VIETNAM
# 17     325           FLOATS GARDEN
# 18     332   FRANKENSTEIN STRANGER
# 19     359      GLADIATOR WESTWARD
# 20     386               GUMP DATE
# 21     404           HATE HANDICAP
# 22     419             HOCUS FRIDA
# 23     495        KENTUCKIAN GIANT
# 24     497        KILL BROTHERHOOD
# 25     607             MUPPET MILE
# 26     642          ORDER BETRAYED
# 27     669           PEARL DESTINY
# 28     671         PERDITION FARGO
# 29     701           PSYCHO SHRUNK
# 30     712       RAIDERS ANTITRUST
# 31     713           RAINBOW SHOCK
# 32     742           ROOF CHAMPION
# 33     801           SISTER FREDDY
# 34     802             SKY MIRACLE
# 35     860        SUICIDES SILENCE
# 36     874            TADPOLE PARK
# 37     909        TREASURE COMMAND
# 38     943       VILLAIN DESPERATE
# 39     950            VOLUME HOUSE
# 40     954               WAKE JAWS
# 41     955            WALLS ARTIST
#
#                                           description release_year  \
# 0   A Emotional Drama of a A Shark And a Database ...         2013
# 1   A Action-Packed Reflection of a Crocodile And ...         2013
# 2   A Emotional Epistle of a Forensic Psychologist...         2011
# 3   A Beautiful Yarn of a Pioneer And a Monkey who...         2009
# 4   A Fanciful Documentary of a Mad Cow And a Woma...         2006
# 5   A Fateful Panorama of a Crocodile And a Boy wh...         2017
# 6   A Lacklusture Yarn of a Feminist And a Databas...         2013
# 7   A Boring Reflection of a Lumberjack And a Femi...         2007
# 8   A Brilliant Panorama of a Technical Writer And...         2013
# 9   A Unbelieveable Story of a Mad Scientist And a...         2009
# 10  A Fanciful Saga of a Student And a Mad Scienti...         2008
# 11  A Beautiful Documentary of a Dog And a Robot w...         2021
# 12  A Intrepid Documentary of a Astronaut And a Fo...         2013
# 13  A Fast-Paced Character Study of a Feminist And...         2012
# 14  A Action-Packed Story of a Pioneer And a Techn...         2008
# 15  A Astounding Saga of a Monkey And a Moose who ...         2011
# 16  A Awe-Inspiring Character Study of a Boat And ...         2010
# 17  A Action-Packed Epistle of a Robot And a Car w...         2018
# 18  A Insightful Character Study of a Feminist And...         2016
# 19  A Astounding Reflection of a Squirrel And a Su...         2020
# 20  A Intrepid Yarn of a Explorer And a Student wh...         2023
# 21  A Intrepid Reflection of a Mad Scientist And a...         2020
# 22  A Awe-Inspiring Tale of a Girl And a Madman wh...         2007
# 23  A Stunning Yarn of a Woman And a Frisbee who m...         2016
# 24  A Touching Display of a Hunter And a Secret Ag...         2007
# 25  A Lacklusture Story of a Madman And a Teacher ...         2018
# 26  A Amazing Saga of a Dog And a A Shark who must...         2022
# 27  A Lacklusture Yarn of a Astronaut And a Pastry...         2010
# 28  A Fast-Paced Story of a Car And a Cat who must...         2023
# 29  A Amazing Panorama of a Crocodile And a Explor...         2013
# 30  A Amazing Drama of a Teacher And a Feminist wh...         2016
# 31  A Action-Packed Story of a Hunter And a Boy wh...         2011
# 32  A Lacklusture Reflection of a Car And a Explor...         2010
# 33  A Stunning Saga of a Butler And a Woman who mu...         2022
# 34  A Epic Drama of a Mad Scientist And a Explorer...         2011
# 35  A Emotional Character Study of a Car And a Gir...         2016
# 36  A Beautiful Tale of a Frisbee And a Moose who ...         2024
# 37  A Emotional Saga of a Car And a Madman who mus...         2015
# 38  A Boring Yarn of a Pioneer And a Feminist who ...         2017
# 39  A Boring Tale of a Dog And a Woman who must Me...         2010
# 40  A Beautiful Saga of a Feminist And a Composer ...         2022
# 41  A Insightful Panorama of a Teacher And a Teach...         2017
#
#    language_id original_language_id rental_duration rental_rate length  \
# 0            4                 None               6        0.99     94
# 1            6                 None               5        2.99    153
# 2            3                 None               7        0.99    127
# 3            1                 None               6        0.99     68
# 4            2                 None               4        0.99    137
# 5            1                 None               7        0.99     76
# 6            6                 None               6        0.99     67
# 7            3                 None               7        0.99    183
# 8            4                 None               7        4.99     61
# 9            1                 None               3        2.99    132
# 10           1                 None               6        4.99     59
# 11           4                 None               4        4.99     50
# 12           2                 None               3        4.99    112
# 13           3                 None               6        2.99    184
# 14           1                 None               6        4.99    120
# 15           1                 None               4        0.99    100
# 16           1                 None               7        0.99    103
# 17           1                 None               6        2.99    145
# 18           1                 None               7        0.99    159
# 19           4                 None               6        4.99    173
# 20           1                 None               3        4.99     53
# 21           4                 None               4        0.99    107
# 22           1                 None               4        2.99    141
# 23           6                 None               5        2.99    169
# 24           1                 None               4        0.99     54
# 25           2                 None               5        4.99     50
# 26           1                 None               7        2.99    120
# 27           1                 None               3        2.99     74
# 28           1                 None               7        4.99     99
# 29           1                 None               5        2.99    155
# 30           1                 None               4        0.99     82
# 31           2                 None               3        4.99     74
# 32           1                 None               7        0.99    101
# 33           1                 None               5        4.99    152
# 34           6                 None               7        2.99    132
# 35           4                 None               4        4.99     93
# 36           2                 None               6        2.99    155
# 37           1                 None               3        0.99    102
# 38           6                 None               4        4.99     76
# 39           1                 None               7        4.99    132
# 40           1                 None               7        4.99     73
# 41           1                 None               7        4.99    135
#
#    replacement_cost rating                    last_update  \
# 0             23.99  NC-17  2022-09-10 18:46:03.905795+02
# 1             15.99  PG-13  2022-09-10 18:46:03.905795+02
# 2             12.99  PG-13  2022-09-10 18:46:03.905795+02
# 3             25.99  NC-17  2022-09-10 18:46:03.905795+02
# 4             17.99     PG  2022-09-10 18:46:03.905795+02
# 5             14.99  NC-17  2022-09-10 18:46:03.905795+02
# 6             19.99  PG-13  2022-09-10 18:46:03.905795+02
# 7             10.99      G  2022-09-10 18:46:03.905795+02
# 8             24.99     PG  2022-09-10 18:46:03.905795+02
# 9             13.99      R  2022-09-10 18:46:03.905795+02
# 10            13.99      R  2022-09-10 18:46:03.905795+02
# 11            19.99      R  2022-09-10 18:46:03.905795+02
# 12            16.99      R  2022-09-10 18:46:03.905795+02
# 13            22.99  NC-17  2022-09-10 18:46:03.905795+02
# 14            20.99      G  2022-09-10 18:46:03.905795+02
# 15             9.99      R  2022-09-10 18:46:03.905795+02
# 16            14.99      G  2022-09-10 18:46:03.905795+02
# 17            29.99  PG-13  2022-09-10 18:46:03.905795+02
# 18            16.99  NC-17  2022-09-10 18:46:03.905795+02
# 19            20.99     PG  2022-09-10 18:46:03.905795+02
# 20            12.99  NC-17  2022-09-10 18:46:03.905795+02
# 21            26.99     PG  2022-09-10 18:46:03.905795+02
# 22            19.99      G  2022-09-10 18:46:03.905795+02
# 23            10.99     PG  2022-09-10 18:46:03.905795+02
# 24            15.99      G  2022-09-10 18:46:03.905795+02
# 25            18.99     PG  2022-09-10 18:46:03.905795+02
# 26            13.99  PG-13  2022-09-10 18:46:03.905795+02
# 27            10.99  NC-17  2022-09-10 18:46:03.905795+02
# 28            27.99  NC-17  2022-09-10 18:46:03.905795+02
# 29            11.99  PG-13  2022-09-10 18:46:03.905795+02
# 30            11.99  PG-13  2022-09-10 18:46:03.905795+02
# 31            14.99     PG  2022-09-10 18:46:03.905795+02
# 32            25.99      R  2022-09-10 18:46:03.905795+02
# 33            19.99  PG-13  2022-09-10 18:46:03.905795+02
# 34            15.99     PG  2022-09-10 18:46:03.905795+02
# 35            13.99      G  2022-09-10 18:46:03.905795+02
# 36            13.99     PG  2022-09-10 18:46:03.905795+02
# 37            28.99  PG-13  2022-09-10 18:46:03.905795+02
# 38            27.99  PG-13  2022-09-10 18:46:03.905795+02
# 39            12.99     PG  2022-09-10 18:46:03.905795+02
# 40            18.99      G  2022-09-10 18:46:03.905795+02
# 41            19.99     PG  2022-09-10 18:46:03.905795+02
#
#                                    special_features  \
# 0                     "{Trailers,""Deleted Scenes""
# 1        "{Trailers,Commentaries,""Deleted Scenes""
# 2                           {Trailers,Commentaries}
# 3        "{Trailers,Commentaries,""Deleted Scenes""
# 4                     "{Trailers,""Deleted Scenes""
# 5                         "{""Behind the Scenes""}"
# 6      "{Trailers,Commentaries,""Deleted Scenes""}"
# 7                "{Trailers,""Behind the Scenes""}"
# 8      "{Trailers,Commentaries,""Deleted Scenes""}"
# 9   "{Trailers,Commentaries,""Behind the Scenes""}"
# 10     "{Trailers,Commentaries,""Deleted Scenes""}"
# 11                "{Commentaries,""Deleted Scenes""
# 12               "{Trailers,""Behind the Scenes""}"
# 13                          {Trailers,Commentaries}
# 14              "{Commentaries,""Deleted Scenes""}"
# 15                           "{""Deleted Scenes""}"
# 16              "{Commentaries,""Deleted Scenes""}"
# 17  "{Trailers,Commentaries,""Behind the Scenes""}"
# 18                             "{""Deleted Scenes""
# 19              "{Commentaries,""Deleted Scenes""}"
# 20                           "{""Deleted Scenes""}"
# 21  "{Trailers,Commentaries,""Behind the Scenes""}"
# 22                    "{Trailers,""Deleted Scenes""
# 23       "{Trailers,Commentaries,""Deleted Scenes""
# 24                          {Trailers,Commentaries}
# 25                  "{Trailers,""Deleted Scenes""}"
# 26                             "{""Deleted Scenes""
# 27                                       {Trailers}
# 28               "{Trailers,""Behind the Scenes""}"
# 29                        "{""Behind the Scenes""}"
# 30                           "{""Deleted Scenes""}"
# 31       "{Trailers,Commentaries,""Deleted Scenes""
# 32                             "{""Deleted Scenes""
# 33               "{Trailers,""Behind the Scenes""}"
# 34     "{Trailers,Commentaries,""Deleted Scenes""}"
# 35                           "{""Deleted Scenes""}"
# 36                          {Trailers,Commentaries}
# 37       "{Trailers,Commentaries,""Deleted Scenes""
# 38                          {Trailers,Commentaries}
# 39                                   {Commentaries}
# 40       "{Trailers,Commentaries,""Deleted Scenes""
# 41               "{Trailers,""Behind the Scenes""}"
#
#                                              fulltext
# 0                             ""Behind the Scenes""}"
# 1                             ""Behind the Scenes""}"
# 2   'abandon':20 'argonaut':1 'butler':12 'challen...
# 3                             ""Behind the Scenes""}"
# 4                             ""Behind the Scenes""}"
# 5   'ballroom':2 'boondock':1 'boy':11 'crocodil':...
# 6   'administr':12 'butch':1 'databas':11 'face':1...
# 7   'amistad':2 'bore':4 'catch':1 'discov':14 'fe...
# 8   'ancient':19 'brilliant':4 'butler':17 'chinat...
# 9   'ancient':20 'china':21 'chocol':1 'compos':18...
# 10  'abandon':20 'battl':15 'command':1 'express':...
# 11                            ""Behind the Scenes""}"
# 12  'abandon':20 'astronaut':8 'crowd':1 'document...
# 13  'ancient':22 'break':2 'charact':7 'chef':20 '...
# 14  'abandon':23 'action':5 'action-pack':4 'amus'...
# 15  'astound':4 'butler':16 'conquer':14 'deliver'...
# 16  'awe':5 'awe-inspir':4 'boat':11 'boy':14 'cha...
# 17  'action':5 'action-pack':4 'ancient':20 'boat'...
# 18                            ""Behind the Scenes""}"
# 19  'ancient':19 'astound':4 'dentist':17 'gladiat...
# 20  'abandon':19 'date':2 'explor':8 'gump':1 'hus...
# 21  'first':20 'handicap':2 'hate':1 'hunter':17 '...
# 22                            ""Behind the Scenes""}"
# 23                            ""Behind the Scenes""}"
# 24  'agent':12 'brotherhood':2 'display':5 'hunter...
# 25  'frisbe':16 'gulf':19 'kill':14 'lacklustur':4...
# 26                            ""Behind the Scenes""}"
# 27  'astronaut':8 'boat':22 'chef':12 'destini':2 ...
# 28  'berlin':20 'car':10 'cat':13 'fargo':2 'fast'...
# 29  'amaz':4 'crocodil':8 'explor':11 'fight':14 '...
# 30  'amaz':4 'antitrust':2 'drama':5 'feminist':11...
# 31                            ""Behind the Scenes""}"
# 32                            ""Behind the Scenes""}"
# 33  'australia':18 'butler':8 'explor':16 'freddi'...
# 34  'abandon':20 'drama':5 'epic':4 'explor':12 'f...
# 35  'boat':22 'car':9 'charact':5 'compos':17 'emo...
# 36  'abandon':19 'amus':20 'beauti':4 'dog':16 'fr...
# 37                            ""Behind the Scenes""}"
# 38  'abandon':19 'amus':20 'bore':4 'cat':16 'desp...
# 39  'bore':4 'california':18 'dentist':16 'dog':8 ...
# 40                            ""Behind the Scenes""}"
# 41  'abandon':20 'artist':2 'cow':17 'fun':21 'hou...

# %%
# 7: топ 3 актеров для категории Children

#  Выбираем категорию Children
children_cat = category.filter(col("name") == "Children")

# Фильмы категории Children
children_films = film_category.join(children_cat, "category_id")

# Соединяем с таблицей film_actor для получения актеров
film_actor = spark.read.option("header", True).csv("data/film_actor.csv")
children_actors = children_films.join(film_actor, "film_id") \
                                .join(actor, "actor_id")

# Считаем количество фильмов на актера
actor_count_children = children_actors.groupBy("first_name", "last_name") \
                                      .agg(count("film_id").alias("film_count")) \
                                      .orderBy(desc("film_count"))

#  Выбираем топ 3 актеров 
top_count = actor_count_children.limit(3).collect()[-1]["film_count"]
top_actors_children = actor_count_children.filter(col("film_count") >= top_count)

#  результат
top_actors_children_pd = top_actors_children.toPandas()
top_actors_children_pd
# Out:
#   first_name last_name  film_count
# 0     SIDNEY     CROWE           9
# 1    RICHARD      PENN           9
# 2       EWAN   GOODING           9

# %%
#  8: активные и неактивные клиенты по городам
customer_city = customer.join(address, "address_id").join(city, "city_id")
city_status = customer_city.groupBy("city") \
    .agg(
        count(col("customer_id")).alias("total_customers"),
        count(col("active")).alias("active_customers"),
        count(col("active")).alias("inactive_customers")
    ).orderBy(desc("inactive_customers"))

city_status_pd = city_status.toPandas()
city_status_pd
# Out:
#                            city  total_customers  active_customers  \
# 0                        London                2                 2
# 1                        Aurora                2                 2
# 2            A Corua (La Corua)                1                 1
# 3                      Fengshan                1                 1
# 4                      Myingyan                1                 1
# ..                          ...              ...               ...
# 592  San Juan Bautista Tuxtepec                1                 1
# 593                      Jelets                1                 1
# 594                     Brescia                1                 1
# 595                   Teboksary                1                 1
# 596  Santiago de los Caballeros                1                 1
#
#      inactive_customers
# 0                     2
# 1                     2
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 592                   1
# 593                   1
# 594                   1
# 595                   1
# 596                   1
#
# [597 rows x 4 columns]

# %%
# 9: категории фильмов с наибольшими часами аренды для городов на "A"
rental_hours = rental.withColumn("rental_hours", (col("return_date").cast("timestamp").cast("long") - col("rental_date").cast("timestamp").cast("long"))/3600)

city_a = city.filter(col("city").startswith("A"))
city_a_rental = rental_hours.join(inventory, "inventory_id") \
    .join(film_category, "film_id") \
    .join(category, "category_id") \
    .join(customer.join(address, "address_id").join(city, "city_id"), "customer_id") \
    .filter(col("city").startswith("A")) \
    .groupBy("name") \
    .agg(spark_sum("rental_hours").alias("total_hours")) \
    .orderBy(desc("total_hours"))

city_a_rental_pd = city_a_rental.toPandas()
city_a_rental_pd

#  для городов с "-"
city_dash = city.filter(col("city").contains("-"))
city_dash_rental = rental_hours.join(inventory, "inventory_id") \
    .join(film_category, "film_id") \
    .join(category, "category_id") \
    .join(customer.join(address, "address_id").join(city, "city_id"), "customer_id") \
    .filter(col("city").contains("-")) \
    .groupBy("name") \
    .agg(spark_sum("rental_hours").alias("total_hours")) \
    .orderBy(desc("total_hours"))

city_dash_rental_pd = city_dash_rental.toPandas()
city_dash_rental_pd
# Out:
#            name   total_hours
# 0         Drama  14556.033333
# 1        Sci-Fi  14251.166667
# 2         Music  13967.983333
# 3         Games  13887.883333
# 4       Foreign  13430.950000
# 5        Travel  12385.183333
# 6        Family  12297.983333
# 7        Sports  11717.500000
# 8        Horror  11707.300000
# 9   Documentary  11418.300000
# 10       Action  11270.916667
# 11          New  10916.166667
# 12    Animation  10828.200000
# 13     Classics  10610.983333
# 14       Comedy   9840.816667
# 15     Children   9691.900000
